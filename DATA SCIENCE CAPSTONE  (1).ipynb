# %% [markdown]
# THIS NOTEBOOK IS FOR A DATA SCIENCE CAPSTONE PROJECT

# %%
import pandas as pd

# %%
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %%
print("week 2")
# Out:
# week 2

# %% [markdown]
# CLUSTERING THE NEIGHBORHOODS OF TORONTO

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
# getting data from internet
wikipedia_link='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
raw_wikipedia_page= requests.get(wikipedia_link).text

# using beautiful soup to parse the HTML/XML codes.
soup = BeautifulSoup(raw_wikipedia_page,'xml')
#print(soup.prettify())

# %% [markdown]
# PROCESSING PART A: EXTRACTING THE RAW TABLE FROM WEBPAGE

# %%
# extracting the raw table inside that webpage
table = soup.find('table')

Postcode      = []
Borough       = []
Neighbourhood = []

# print(table)

# extracting a clean form of the table
for tr_cell in table.find_all('tr'):
    
    counter = 1
    Postcode_var      = -1
    Borough_var       = -1
    Neighbourhood_var = -1
    
    for td_cell in tr_cell.find_all('td'):
        if counter == 1: 
            Postcode_var = td_cell.text
        if counter == 2: 
            Borough_var = td_cell.text
            tag_a_Borough = td_cell.find('a')
       
        if counter == 3: 
            Neighbourhood_var = str(td_cell.text).strip()
            tag_a_Neighbourhood = td_cell.find('a')
            
        counter +=1
        
    if (Postcode_var == 'Not assigned' or Borough_var == 'Not assigned' or Neighbourhood_var == 'Not assigned'): 
        continue
    try:
        if ((tag_a_Borough is None) or (tag_a_Neighbourhood is None)):
            continue
    except:
        pass
    if(Postcode_var == -1 or Borough_var == -1 or Neighbourhood_var == -1):
        continue
        
    Postcode.append(Postcode_var)
    Borough.append(Borough_var)
    Neighbourhood.append(Neighbourhood_var)

# %% [markdown]
# PROCESSING PART B:INTEGRATING POSTAL CODES WITH MORE THAN ONE NEIGHBOUR

# %%
unique_p = set(Postcode)
print('num of unique Postal codes:', len(unique_p))
Postcode_u      = []
Borough_u       = []
Neighbourhood_u = []


for postcode_unique_element in unique_p:
    p_var = ''; b_var = ''; n_var = ''; 
    for postcode_idx, postcode_element in enumerate(Postcode):
        if postcode_unique_element == postcode_element:
            p_var = postcode_element;
            b_var = Borough[postcode_idx]
            if n_var == '': 
                n_var = Neighbourhood[postcode_idx]
            else:
                n_var = n_var + ', ' + Neighbourhood[postcode_idx]
    Postcode_u.append(p_var)
    Borough_u.append(b_var)
    Neighbourhood_u.append(n_var)
# Out:
# num of unique Postal codes: 84

# %% [markdown]
# POST-PROCESSING: CREATING AN APPROPRIATE PANDAS DATAFRAME

# %%
toronto_dict = {'Postcode':Postcode_u, 'Borough':Borough_u, 'Neighbourhood':Neighbourhood_u}
df_toronto = pd.DataFrame.from_dict(toronto_dict)
df_toronto.to_csv('toronto_part1.csv')
df_toronto.head(14)
# Out:
#          Borough                                      Neighbourhood Postcode
# 0     North York                                          Parkwoods      M3A
# 1     North York                                  Hillcrest Village      M2H
# 2    Scarborough             Highland Creek, Rouge Hill, Port Union      M1C
# 3     North York                                       Bedford Park      M5M
# 4      East York                                   Woodbine Heights      M4C
# 5     North York                    Northwood Park, York University      M3J
# 6     North York                                        CFB Toronto      M3K
# 7      Etobicoke  Humber Bay, King's Mill Park, Mimico NE, Old M...      M8Y
# 8    Scarborough                    Clairlea, Golden Mile, Oakridge      M1L
# 9           York                                             Weston      M9N
# 10    North York                            Newtonbrook, Willowdale      M2M
# 11    North York                           Silver Hills, York Mills      M2L
# 12  West Toronto                             Parkdale, Roncesvalles      M6R
# 13   Scarborough                                        Birch Cliff      M1N

# %%
df_toronto.shape
# Out:
# (84, 3)
